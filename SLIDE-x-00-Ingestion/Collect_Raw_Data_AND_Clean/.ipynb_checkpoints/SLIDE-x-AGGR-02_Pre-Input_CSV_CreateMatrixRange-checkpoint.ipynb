# %%
# Declarations
import glob
import json
import os
import numpy as np
import pandas as pd

from os.path import basename

# %%
# DataFrame name json file
nameFile = []
pathFile = []
rootFile = []

path = os.getcwd()
for root, dirs, files in os.walk('../../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT'):
    for file in files:
        if file.endswith(".json"):
            nameFile.append(file)
            pathFile.append(os.path.join(root, file))
            rootFile.append(root)
            
nameFileS = pd.Series(nameFile)
pathFileS = pd.Series(pathFile)
rootFileS = pd.Series(rootFile)

pd.options.display.max_colwidth = 100
print('nameFileS:'+nameFileS)
print('pathFileS:'+pathFileS)
print('rootFileS:'+rootFileS)

dfNF = pd.concat([nameFileS, pathFileS, rootFileS], axis=1)
dfNF.columns = ['FILE_NAME', 'FILE_PATH', 'FILE_ROOT']
# Out:
# 0    nameFileS:parameters.json
# 1    nameFileS:parameters.json
# 2    nameFileS:parameters.json
# dtype: object
# 0          pathFileS:../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT\bs\parameters.json
# 1    pathFileS:../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT\bsort100\parameters.json
# 2         pathFileS:../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT\cnt\parameters.json
# dtype: object
# 0          rootFileS:../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT\bs
# 1    rootFileS:../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT\bsort100
# 2         rootFileS:../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT\cnt
# dtype: object

# %%
# .json file loop
df = pd.DataFrame(columns=['DEVICE','FUNCTION','DATA_TYPE',
                           'NUM_S','RANGE_S','NUM_SI','RANGE_SI',
                           'NUM_ARR','RANGE_ARR'])  # 'BOARD',

listD = ["Arm","Atmega328p","Leon3","RiscV","Thumb"] # Inserisci i dispositivi che vuoi analizzare
listDT = ["int8_t","int16_t","int32_t","int64_t"] # Inserisci i data type che vuoi analizzare

# %%
for i in range(0, len(pathFile)):
    pF = pathFile[i]
    print('pF:'+str(pF))

    with open(pF, 'r') as jf:
        data = jf.read()
    obj = json.loads(data)

    if os.name == 'nt':
        spR = rootFile[i].split('\\')
        print('spR:'+str(spR))
    else:
        spR = rootFile[i].split('/')
        print('spR:'+str(spR))
    
    function = spR[-1]
    print('function:'+str(function))
    # board = listD[i]
    # print('board:'+str(board))
    
    #Device loop
    deviceList = list(obj.keys())
    print('deviceList:'+str(deviceList))
    deviceListR = []
    for u in range(0, len(deviceList)):
        if deviceList[u] in listD:
            deviceListR.append(deviceList[u])
            print('deviceListR:'+str(deviceList[u]))

    for n in range(0, len(deviceListR)):
        # Data_type loop
        device = deviceListR[n]
        print('device:'+str(device))
        dtarr = list(obj[deviceListR[n]].keys())
        print('dtarr:'+str(dtarr))
        
        dtarrR = []
        for u in range(0, len(dtarr)):
            if dtarr[u] in listDT:
                dtarrR.append(dtarr[u])
                print(f'dtarr[{u}]:'+str(dtarr[u]))
        
        for j in range(0, len(dtarrR)):
            dataype = dtarrR[j]
            print('dataype:'+str(dtarrR[j]))
            lsubNP = (list(obj[deviceListR[n]][dtarrR[j]].keys()))
            print('lsubNP:'+str(lsubNP))
            lsubVP = (list(obj[deviceListR[n]][dtarrR[j]].values()))
            print('lsubVP:'+str(lsubVP))
            
            # sublist dimension
            ltot = len(lsubNP)
            print('ltot:'+str(ltot))
            
            # how many array are present
            na = 0
            fl = 0
            
            ark = 0
            
            for k in range(0, ltot): 
                #print(function, fl)
                if "[" in lsubNP[k]:
                    na = na + 1
                    if fl == 0:
                        ark = k
                        fl = 1

            # how many scalar index are present
            nsi = 0
            for k in range(0, ltot):
                flag = 0
                if not "[" in lsubNP[k]:
                    for keysl in lsubNP:
                        if (lsubNP[k] in keysl) and (not lsubNP[k] is keysl) and (flag == 0):          
                            flag = 1
                            nsi = nsi + 1           

            # how many scalar are present
            ns = ltot - na - nsi

            # check if is it negative
            newstr = lsubVP[ark].replace("[", "")
            newstr = newstr.replace("]", "")
            newstr = newstr.split(",")[0]
            num = float(newstr)
            ranArr = 0
            if num < 0:
                ranArr = 1
            else:
                ranArr = 0

            df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
                            'NUM_S': ns, 'RANGE_S': 0,'NUM_SI': nsi,'RANGE_SI': 0,
                            'NUM_ARR': na,'RANGE_ARR': ranArr}, 
                            ignore_index=True)  # 'BOARD': board,
# Out:
# pF:../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT\bs\parameters.json
# spR:['../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT', 'bs']
# function:bs
# deviceList:['args', 'ALL', 'Arm', 'Thumb', 'Atmega328p', '8051', 'Leon3', 'RiscV']
# deviceListR:Arm
# deviceListR:Thumb
# deviceListR:Atmega328p
# deviceListR:Leon3
# deviceListR:RiscV
# device:Arm
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-128,127]', '[2,32];10']
# ltot:3
# dataype:int16_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-32766,32766]', '[2,23];10']
# ltot:3
# dataype:int32_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,23];10', '[-32766,32766]', '[2,23];10']
# ltot:3
# dataype:int64_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-32766,32766]', '[2,32];10']
# ltot:3
# device:Thumb
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-128,127]', '[2,32];10']
# ltot:3
# dataype:int16_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-32766,32766]', '[2,32];10']
# ltot:3
# dataype:int32_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-32766,32766]', '[2,32];10']
# ltot:3
# dataype:int64_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-32766,32766]', '[2,32];10']
# ltot:3
# device:Atmega328p
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'uint16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[4]:int32_t
# dtarr[5]:int64_t
# dataype:int8_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-126,126]', '[2,32];10']
# ltot:3
# dataype:int16_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-32766,32766]', '[2,32];10']
# ltot:3
# dataype:int32_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-2147483640,2147483640]', '[2,32];10']
# ltot:3
# dataype:int64_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-9223372036854775808,9223372036854775807]', '[2,32];10']
# ltot:3
# device:Leon3
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'uint16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[4]:int32_t
# dtarr[5]:int64_t
# dataype:int8_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-126,126]', '[2,32];10']
# ltot:3
# dataype:int16_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-32766,32766]', '[2,32];10']
# ltot:3
# dataype:int32_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-2147483640,2147483640]', '[2,32];10']
# ltot:3
# dataype:int64_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-9223372036854775808,9223372036854775807]', '[2,32];10']
# ltot:3
# device:RiscV
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'uint16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[4]:int32_t
# dtarr[5]:int64_t
# dataype:int8_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-126,126]', '[2,32];10']
# ltot:3
# dataype:int16_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-32766,32766]', '[2,32];10']
# ltot:3
# dataype:int32_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-2147483640,2147483640]', '[2,32];10']
# ltot:3
# dataype:int64_t
# lsubNP:['n', 'arr[n]', 'key']
# lsubVP:['[2,32];10', '[-9223372036854775808,9223372036854775807]', '[2,32];10']
# ltot:3
# pF:../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT\bsort100\parameters.json
# spR:['../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT', 'bsort100']
# function:bsort100
# deviceList:['args', 'ALL', 'Arm', 'Thumb', '8051', 'Atmega328p', 'Leon3', 'RiscV', 'Bambu']
# deviceListR:Arm
# deviceListR:Thumb
# deviceListR:Atmega328p
# deviceListR:Leon3
# deviceListR:RiscV
# device:Arm
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-128,127]']
# ltot:2
# dataype:int16_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-32766,32766]']
# ltot:2
# dataype:int32_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-2147483640,2147483640]']
# ltot:2
# dataype:int64_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-9223372036854775808,9223372036854775807]']
# ltot:2
# device:Thumb
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-128,127]']
# ltot:2
# dataype:int16_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-32766,32766]']
# ltot:2
# dataype:int32_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-2147483640,2147483640]']
# ltot:2
# dataype:int64_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-9223372036854775808,9223372036854775807]']
# ltot:2
# device:Atmega328p
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-128,127]']
# ltot:2
# dataype:int16_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-32766,32766]']
# ltot:2
# dataype:int32_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-2147483640,2147483640]']
# ltot:2
# dataype:int64_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-9223372036854775808,9223372036854775807]']
# ltot:2
# device:Leon3
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-128,127]']
# ltot:2
# dataype:int16_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-32766,32766]']
# ltot:2
# dataype:int32_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-2147483640,2147483640]']
# ltot:2
# dataype:int64_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-9223372036854775808,9223372036854775807]']
# ltot:2
# device:RiscV
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-128,127]']
# ltot:2
# dataype:int16_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-32766,32766]']
# ltot:2
# dataype:int32_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-2147483640,2147483640]']
# ltot:2
# dataype:int64_t
# lsubNP:['size', 'a[size]']
# lsubVP:['[2,32];100', '[-9223372036854775808,9223372036854775807]']
# ltot:2
# pF:../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT\cnt\parameters.json
# spR:['../../SLIDE-x/SLIDE-x-AGGR-RESULTS/RECIPE_INT', 'cnt']
# function:cnt
# deviceList:['args', 'ALL', 'Arm', 'Thumb', '8051', 'Atmega328p', 'Leon3', 'RiscV', 'Bambu']
# deviceListR:Arm
# deviceListR:Thumb
# deviceListR:Atmega328p
# deviceListR:Leon3
# deviceListR:RiscV
# device:Arm
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-128,127]']
# ltot:2
# dataype:int16_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-32766,32766]']
# ltot:2
# dataype:int32_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-2147483640,2147483640]']
# ltot:2
# dataype:int64_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-9223372036854775808,9223372036854775807]']
# ltot:2
# device:Thumb
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-128,127]']
# ltot:2
# dataype:int16_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-32766,32766]']
# ltot:2
# dataype:int32_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-2147483640,2147483640]']
# ltot:2
# dataype:int64_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-9223372036854775808,9223372036854775807]']
# ltot:2
# device:Atmega328p
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-128,127]']
# ltot:2
# dataype:int16_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-32766,32766]']
# ltot:2
# dataype:int32_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-2147483640,2147483640]']
# ltot:2
# dataype:int64_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-9223372036854775808,9223372036854775807]']
# ltot:2
# device:Leon3
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-128,127]']
# ltot:2
# dataype:int16_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-32766,32766]']
# ltot:2
# dataype:int32_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-2147483640,2147483640]']
# ltot:2
# dataype:int64_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-9223372036854775808,9223372036854775807]']
# ltot:2
# device:RiscV
# dtarr:['int8_t', 'uint8_t', 'int16_t', 'int32_t', 'int64_t', 'float', 'double']
# dtarr[0]:int8_t
# dtarr[2]:int16_t
# dtarr[3]:int32_t
# dtarr[4]:int64_t
# dataype:int8_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-128,127]']
# ltot:2
# dataype:int16_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-32766,32766]']
# ltot:2
# dataype:int32_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-2147483640,2147483640]']
# ltot:2
# dataype:int64_t
# lsubNP:['size', 'a[size][size]']
# lsubVP:['[2,32];100', '[-9223372036854775808,9223372036854775807]']
# ltot:2
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,
# C:\Users\vitto\AppData\Local\Temp\ipykernel_7976\3274154910.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'DEVICE': device, 'FUNCTION': function, 'DATA_TYPE': dataype,

# %%
dfS = pd.read_csv("dfS.csv", sep=';')
dfSI = pd.read_csv("dfSI.csv", sep=';')

# %%
dfS = pd.read_csv("dfS_tot.csv", sep=';')
dfSI = pd.read_csv("dfSI_tot.csv", sep=';')

# %%
del dfS['Unnamed: 0']
del dfSI['Unnamed: 0']

# %%
columnsS = ['DEVICE','FUNCTION','DATA_TYPE','RANGE_S']
columnsSI = ['DEVICE','FUNCTION','DATA_TYPE','RANGE_SI']
dfS = dfS[columnsS]
dfSI = dfSI[columnsSI]

# %%
lent = len(dfS['RANGE_S'].tolist())
for i in range(0, lent):
    df.loc[(df['DEVICE'] == dfS['DEVICE'][i]) & 
           # (df['BOARD'] == dfS['BOARD'][i]) &
           (df['FUNCTION'] == dfS['FUNCTION'][i]) & 
           (df['DATA_TYPE'] == dfS['DATA_TYPE'][i]), 'RANGE_S'] = dfS['RANGE_S'][i]

# %%
lent = len(dfSI['RANGE_SI'].tolist())
for i in range(0, lent):
    df.loc[(df['DEVICE'] == dfSI['DEVICE'][i]) & 
           # (df['BOARD'] == dfSI['BOARD'][i]) & 
           (df['FUNCTION'] == dfSI['FUNCTION'][i]) & 
           (df['DATA_TYPE'] == dfSI['DATA_TYPE'][i]), 'RANGE_SI'] = dfSI['RANGE_SI'][i]

# %%
df.to_csv("RangeValueClassification_tot.csv", sep=';')
